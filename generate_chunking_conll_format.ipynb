# %%
# !pip install spacy_conll[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 574 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 304 kB 41.9 MB/s
# ...
#      |████████████████████████████████| 175 kB 40.2 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 21.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 31.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 41.8 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.0 MB/s
# ...
#   Created wheel for ufal.udpipe: filename=ufal.udpipe-1.2.0.3-cp37-cp37m-linux_x86_64.whl size=5626674 sha256=ab79a797c83355da48a159338818102850bac6f0a6ebbdd20596437460480aee
#   Stored in directory: /root/.cache/pip/wheels/b8/b5/8e/3da091629a21ce2d10bf90759d0cb034ba10a5cf7a01e83d64
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=f2f6922b02c0834c8449468fd0097da58313baf5cdda1d34c237ec6b7a7862d5
# ...

# %%
from spacy_conll import init_parser


# Initialise English parser, already including the ConllFormatter as a pipeline component.
# Indicate that we want to get the CoNLL headers in the string output.
# `use_gpu` and `verbose` are specific to stanza. These keywords arguments are passed onto their Pipeline() initialisation
nlp = init_parser("en",
                  "stanza",
                  parser_opts={"use_gpu": True, "verbose": False},
                  include_headers=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9304da92-81d0-4c3b-bb5a-eee2f20d24d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9304da92-81d0-4c3b-bb5a-eee2f20d24d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 21styear_transcript.txt to 21styear_transcript.txt

# %%
story_text = open("21styear_transcript.txt","r")
data = story_text.read()

# %%
# Parse a given string
doc = nlp(data)

# Get the CoNLL representation of the whole document, including headers
conll = doc._.conll_str
print(conll)
# Out:
# # sent_id = 1
# # text = This is Los Angeles.
# 1	This	this	PRON	DT	Number=Sing|PronType=Dem	3	nsubj	_	_
# 2	is	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	3	cop	_	_
# 3	Los	Los	PROPN	NNP	Number=Sing	0	root	_	_
# 4	Angeles	Angeles	PROPN	NNP	Number=Sing	3	flat	_	SpaceAfter=No
# 5	.	.	PUNCT	.	_	3	punct	_	_
#
# # sent_id = 2
# # text = And it's the height of summer.
# 1	And	and	CCONJ	CC	_	5	cc	_	_
# 2	it	it	PRON	PRP	Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs	5	nsubj	_	SpaceAfter=No
# 3	's	be	AUX	VBZ	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	cop	_	_
# 4	the	the	DET	DT	Definite=Def|PronType=Art	5	det	_	_
# 5	height	height	NOUN	NN	Number=Sing	0	root	_	_
# 6	of	of	ADP	IN	_	7	case	_	_
# 7	summer	summer	NOUN	NN	Number=Sing	5	nmod	_	SpaceAfter=No
# 8	.	.	PUNCT	.	_	5	punct	_	_
#
# # sent_id = 3
# # text = In a small bungalow off of La Cienega, Clara serves homemade chili and chips in red plastic bowls -- wine in blue plastic.
# ...

# %%
with open('phrasal_syntax_21styear.txt', 'w') as f:
    f.write(conll)

# %%
files.download('phrasal_syntax_21styear.txt')
